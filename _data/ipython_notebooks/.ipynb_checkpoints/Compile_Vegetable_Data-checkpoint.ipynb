# %%
import pandas as pd
import numpy as np

pieces = []
columns = ["State","State_ANSI", "Ag_District", "Ag_District_Code", "County", 
           "County_ANSI","Commodity","Data_Item", "Domain", "Domain_Category", "Value", "CV", "FIPS"]

for i in range(1, 7):
    path = 'farm_data/veggies_by_county_{0}.csv'.format(i)
    frame = pd.read_csv(path, names=columns, skiprows=1)

    pieces.append(frame)
    
# Concatenate everything into a single DataFrame
veg_df = pd.concat(pieces, ignore_index=True)

# %%
# make strings to concatenate into FIPS codes
veg_df.State_ANSI = veg_df.State_ANSI.astype(str)
veg_df.County_ANSI = veg_df.County_ANSI.astype(str)

# more readable in title case than all caps
veg_df.State = veg_df.apply(lambda x: x.State.title(), axis = 1)
veg_df.County = veg_df.apply(lambda x: x.County.title(), axis = 1)
veg_df.Commodity = veg_df.apply(lambda x: x.Commodity.title(), axis = 1)

# %%
def prepend_zeros(row):
    if len(row.County_ANSI) == 1:
        return ''.join(['00', row.County_ANSI])
    elif len(row.County_ANSI) == 2:
        return ''.join(['0', row.County_ANSI])
    else:
        return row.County_ANSI

veg_df.County_ANSI = veg_df.apply(prepend_zeros, axis=1)

# %%
# index by combined ids
veg_df.FIPS = veg_df.apply(lambda row: ''.join([row.State_ANSI, row.County_ANSI]), axis = 1)
veg_df.tail(30)
# Out:
#           State State_ANSI Ag_District  Ag_District_Code    County  \
# 226176  Wyoming         56        WEST                30   Lincoln
# 226177  Wyoming         56        WEST                30  Sublette
# 226178  Wyoming         56        WEST                30  Sublette
# 226179  Wyoming         56        WEST                30  Sublette
# 226180  Wyoming         56        WEST                30  Sublette
# 226181  Wyoming         56        WEST                30  Sublette
# 226182  Wyoming         56        WEST                30  Sublette
# 226183  Wyoming         56        WEST                30  Sublette
# 226184  Wyoming         56        WEST                30  Sublette
# 226185  Wyoming         56        WEST                30  Sublette
# 226186  Wyoming         56        WEST                30  Sublette
# 226187  Wyoming         56        WEST                30  Sublette
# 226188  Wyoming         56        WEST                30  Sublette
# 226189  Wyoming         56        WEST                30  Sublette
# 226190  Wyoming         56        WEST                30  Sublette
# 226191  Wyoming         56        WEST                30  Sublette
# 226192  Wyoming         56        WEST                30  Sublette
# 226193  Wyoming         56        WEST                30  Sublette
# 226194  Wyoming         56        WEST                30  Sublette
# 226195  Wyoming         56        WEST                30  Sublette
# 226196  Wyoming         56        WEST                30  Sublette
# 226197  Wyoming         56        WEST                30  Sublette
# 226198  Wyoming         56        WEST                30  Sublette
# 226199  Wyoming         56        WEST                30  Sublette
# 226200  Wyoming         56        WEST                30  Sublette
# 226201  Wyoming         56        WEST                30  Sublette
# 226202  Wyoming         56        WEST                30  Sublette
# 226203  Wyoming         56        WEST                30  Sublette
# 226204  Wyoming         56        WEST                30  Sublette
# 226205  Wyoming         56        WEST                30  Sublette
#
#        County_ANSI         Commodity  \
# 226176         023  Vegetable Totals
# 226177         035           Cabbage
# 226178         035           Cabbage
# 226179         035           Cabbage
# 226180         035           Cabbage
# 226181         035           Carrots
# 226182         035           Carrots
# 226183         035           Carrots
# 226184         035           Carrots
# 226185         035            Greens
# 226186         035            Greens
# 226187         035            Greens
# 226188         035            Greens
# 226189         035           Lettuce
# 226190         035           Lettuce
# 226191         035           Lettuce
# 226192         035           Lettuce
# 226193         035           Lettuce
# 226194         035           Lettuce
# 226195         035           Lettuce
# 226196         035           Lettuce
# 226197         035              Peas
# 226198         035              Peas
# 226199         035              Peas
# 226200         035              Peas
# 226201         035  Vegetable Totals
# 226202         035  Vegetable Totals
# 226203         035  Vegetable Totals
# 226204         035  Vegetable Totals
# 226205         035  Vegetable Totals
#
#                                                 Data_Item  \
# 226176  VEGETABLE TOTALS, IN THE OPEN, FRESH MARKET - ...
# 226177                    CABBAGE, HEAD - ACRES HARVESTED
# 226178     CABBAGE, HEAD - OPERATIONS WITH AREA HARVESTED
# 226179      CABBAGE, HEAD, FRESH MARKET - ACRES HARVESTED
# 226180  CABBAGE, HEAD, FRESH MARKET - OPERATIONS WITH ...
# 226181                          CARROTS - ACRES HARVESTED
# 226182           CARROTS - OPERATIONS WITH AREA HARVESTED
# 226183            CARROTS, FRESH MARKET - ACRES HARVESTED
# 226184  CARROTS, FRESH MARKET - OPERATIONS WITH AREA H...
# 226185                     GREENS, KALE - ACRES HARVESTED
# 226186      GREENS, KALE - OPERATIONS WITH AREA HARVESTED
# 226187       GREENS, KALE, FRESH MARKET - ACRES HARVESTED
# 226188  GREENS, KALE, FRESH MARKET - OPERATIONS WITH A...
# 226189                          LETTUCE - ACRES HARVESTED
# 226190           LETTUCE - OPERATIONS WITH AREA HARVESTED
# 226191            LETTUCE, FRESH MARKET - ACRES HARVESTED
# 226192  LETTUCE, FRESH MARKET - OPERATIONS WITH AREA H...
# 226193                    LETTUCE, LEAF - ACRES HARVESTED
# 226194     LETTUCE, LEAF - OPERATIONS WITH AREA HARVESTED
# 226195      LETTUCE, LEAF, FRESH MARKET - ACRES HARVESTED
# 226196  LETTUCE, LEAF, FRESH MARKET - OPERATIONS WITH ...
# 226197     PEAS, GREEN, (EXCL SOUTHERN) - ACRES HARVESTED
# 226198  PEAS, GREEN, (EXCL SOUTHERN) - OPERATIONS WITH...
# 226199  PEAS, GREEN, (EXCL SOUTHERN), FRESH MARKET - A...
# 226200  PEAS, GREEN, (EXCL SOUTHERN), FRESH MARKET - O...
# 226201    VEGETABLE TOTALS, IN THE OPEN - ACRES HARVESTED
# 226202  VEGETABLE TOTALS, IN THE OPEN - OPERATIONS WIT...
# 226203  VEGETABLE TOTALS, IN THE OPEN - OPERATIONS WIT...
# 226204  VEGETABLE TOTALS, IN THE OPEN, FRESH MARKET - ...
# 226205  VEGETABLE TOTALS, IN THE OPEN, FRESH MARKET - ...
#
#                                            Domain  \
# 226176                                      TOTAL
# 226177                                      TOTAL
# 226178                                      TOTAL
# 226179                                      TOTAL
# 226180                                      TOTAL
# 226181                                      TOTAL
# 226182                                      TOTAL
# 226183                                      TOTAL
# 226184                                      TOTAL
# 226185                                      TOTAL
# 226186                                      TOTAL
# 226187                                      TOTAL
# 226188                                      TOTAL
# 226189                                      TOTAL
# 226190                                      TOTAL
# 226191                                      TOTAL
# 226192                                      TOTAL
# 226193                                      TOTAL
# 226194                                      TOTAL
# 226195                                      TOTAL
# 226196                                      TOTAL
# 226197                                      TOTAL
# 226198                                      TOTAL
# 226199                                      TOTAL
# 226200                                      TOTAL
# 226201                                      TOTAL
# 226202  AREA HARVESTED, FRESH MARKET & PROCESSING
# 226203                                      TOTAL
# 226204                                      TOTAL
# 226205                                      TOTAL
#
#                                           Domain_Category Value    CV   FIPS
# 226176                                      NOT SPECIFIED     2  54.2  56023
# 226177                                      NOT SPECIFIED   (D)   (D)  56035
# 226178                                      NOT SPECIFIED     1   NaN  56035
# 226179                                      NOT SPECIFIED   (D)   (D)  56035
# 226180                                      NOT SPECIFIED     1   NaN  56035
# 226181                                      NOT SPECIFIED   (D)   (D)  56035
# 226182                                      NOT SPECIFIED     1   NaN  56035
# 226183                                      NOT SPECIFIED   (D)   (D)  56035
# 226184                                      NOT SPECIFIED     1   NaN  56035
# 226185                                      NOT SPECIFIED   (D)   (D)  56035
# 226186                                      NOT SPECIFIED     1   NaN  56035
# 226187                                      NOT SPECIFIED   (D)   (D)  56035
# 226188                                      NOT SPECIFIED     1   NaN  56035
# 226189                                      NOT SPECIFIED   (D)   (D)  56035
# 226190                                      NOT SPECIFIED     1   NaN  56035
# 226191                                      NOT SPECIFIED   (D)   (D)  56035
# 226192                                      NOT SPECIFIED     1   NaN  56035
# 226193                                      NOT SPECIFIED   (D)   (D)  56035
# 226194                                      NOT SPECIFIED     1   NaN  56035
# 226195                                      NOT SPECIFIED   (D)   (D)  56035
# 226196                                      NOT SPECIFIED     1   NaN  56035
# 226197                                      NOT SPECIFIED   (D)   (D)  56035
# 226198                                      NOT SPECIFIED     1   NaN  56035
# 226199                                      NOT SPECIFIED   (D)   (D)  56035
# 226200                                      NOT SPECIFIED     1   NaN  56035
# 226201                                      NOT SPECIFIED   (D)   (D)  56035
# 226202  AREA HARVESTED, FRESH MARKET & PROCESSING: (0....     1  55.9  56035
# 226203                                      NOT SPECIFIED     1  54.2  56035
# 226204                                      NOT SPECIFIED   (D)   (D)  56035
# 226205                                      NOT SPECIFIED     1  54.2  56035
#
# [30 rows x 13 columns]

# %%
veg_df2 = veg_df.Data_Item.apply(lambda x: pd.Series(x.split('- ')))
veg_df2.columns = ['Spec_Commodity', 'Measure']
veg_df2.head()
# Out:
#                Spec_Commodity                         Measure
# 0                BEANS, SNAP                  ACRES HARVESTED
# 1                BEANS, SNAP   OPERATIONS WITH AREA HARVESTED
# 2  BEANS, SNAP, FRESH MARKET                  ACRES HARVESTED
# 3  BEANS, SNAP, FRESH MARKET   OPERATIONS WITH AREA HARVESTED
# 4    BEANS, SNAP, PROCESSING                  ACRES HARVESTED
#
# [5 rows x 2 columns]

# %%
veg_df3 = pd.merge(veg_df, veg_df2, left_index= True, right_index= True)

# %%
veg_df3[(veg_df3.Commodity == 'Eggplant') & (veg_df3.County == "Lancaster")]
# Out:
#                State State_ANSI   Ag_District  Ag_District_Code     County  \
# 118437      Nebraska         31          EAST                60  Lancaster
# 118438      Nebraska         31          EAST                60  Lancaster
# 118439      Nebraska         31          EAST                60  Lancaster
# 118440      Nebraska         31          EAST                60  Lancaster
# 171258  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
# 171259  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
# 171260  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
# 171261  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
# 171262  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
# 171263  Pennsylvania         42  SOUTHEASTERN                90  Lancaster
#
#        County_ANSI Commodity  \
# 118437         109  Eggplant
# 118438         109  Eggplant
# 118439         109  Eggplant
# 118440         109  Eggplant
# 171258         071  Eggplant
# 171259         071  Eggplant
# 171260         071  Eggplant
# 171261         071  Eggplant
# 171262         071  Eggplant
# 171263         071  Eggplant
#
#                                                 Data_Item Domain  \
# 118437                         EGGPLANT - ACRES HARVESTED  TOTAL
# 118438          EGGPLANT - OPERATIONS WITH AREA HARVESTED  TOTAL
# 118439           EGGPLANT, FRESH MARKET - ACRES HARVESTED  TOTAL
# 118440  EGGPLANT, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 171258                         EGGPLANT - ACRES HARVESTED  TOTAL
# 171259          EGGPLANT - OPERATIONS WITH AREA HARVESTED  TOTAL
# 171260           EGGPLANT, FRESH MARKET - ACRES HARVESTED  TOTAL
# 171261  EGGPLANT, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 171262             EGGPLANT, PROCESSING - ACRES HARVESTED  TOTAL
# 171263  EGGPLANT, PROCESSING - OPERATIONS WITH AREA HA...  TOTAL
#
#        Domain_Category Value    CV   FIPS           Spec_Commodity  \
# 118437   NOT SPECIFIED   (D)   (D)  31109                EGGPLANT
# 118438   NOT SPECIFIED     2   (H)  31109                EGGPLANT
# 118439   NOT SPECIFIED   (D)   (D)  31109  EGGPLANT, FRESH MARKET
# 118440   NOT SPECIFIED     2   (H)  31109  EGGPLANT, FRESH MARKET
# 171258   NOT SPECIFIED    15  28.2  42071                EGGPLANT
# 171259   NOT SPECIFIED    33  31.7  42071                EGGPLANT
# 171260   NOT SPECIFIED   (D)   (D)  42071  EGGPLANT, FRESH MARKET
# 171261   NOT SPECIFIED    33  31.7  42071  EGGPLANT, FRESH MARKET
# 171262   NOT SPECIFIED   (D)   (D)  42071    EGGPLANT, PROCESSING
# 171263   NOT SPECIFIED     2  93.7  42071    EGGPLANT, PROCESSING
#
#                                Measure
# 118437                 ACRES HARVESTED
# 118438  OPERATIONS WITH AREA HARVESTED
# 118439                 ACRES HARVESTED
# 118440  OPERATIONS WITH AREA HARVESTED
# 171258                 ACRES HARVESTED
# 171259  OPERATIONS WITH AREA HARVESTED
# 171260                 ACRES HARVESTED
# 171261  OPERATIONS WITH AREA HARVESTED
# 171262                 ACRES HARVESTED
# 171263  OPERATIONS WITH AREA HARVESTED
#
# [10 rows x 15 columns]

# %%
veg_df3.head()
# Out:
#      State State_ANSI Ag_District  Ag_District_Code   County County_ANSI  \
# 0  Alabama          1  BLACK BELT                40  Autauga         001
# 1  Alabama          1  BLACK BELT                40  Autauga         001
# 2  Alabama          1  BLACK BELT                40  Autauga         001
# 3  Alabama          1  BLACK BELT                40  Autauga         001
# 4  Alabama          1  BLACK BELT                40  Autauga         001
#
#   Commodity                                          Data_Item Domain  \
# 0     Beans                      BEANS, SNAP - ACRES HARVESTED  TOTAL
# 1     Beans       BEANS, SNAP - OPERATIONS WITH AREA HARVESTED  TOTAL
# 2     Beans        BEANS, SNAP, FRESH MARKET - ACRES HARVESTED  TOTAL
# 3     Beans  BEANS, SNAP, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 4     Beans          BEANS, SNAP, PROCESSING - ACRES HARVESTED  TOTAL
#
#   Domain_Category Value    CV  FIPS              Spec_Commodity  \
# 0   NOT SPECIFIED    12   (H)  1001                BEANS, SNAP
# 1   NOT SPECIFIED     8  31.5  1001                BEANS, SNAP
# 2   NOT SPECIFIED   (D)   (D)  1001  BEANS, SNAP, FRESH MARKET
# 3   NOT SPECIFIED     7  32.6  1001  BEANS, SNAP, FRESH MARKET
# 4   NOT SPECIFIED   (D)   (D)  1001    BEANS, SNAP, PROCESSING
#
#                           Measure
# 0                 ACRES HARVESTED
# 1  OPERATIONS WITH AREA HARVESTED
# 2                 ACRES HARVESTED
# 3  OPERATIONS WITH AREA HARVESTED
# 4                 ACRES HARVESTED
#
# [5 rows x 15 columns]

# %%
# isolate Value column for rows that correspond to fresh market acres harvested, create boolean mask
test_series = veg_df3[veg_df3.Data_Item.str.contains("FRESH MARKET") & (veg_df3.Measure == "ACRES HARVESTED")].Value.str.contains("(D)")

# proportion of True/Total
float(np.sum(test_series))/len(test_series)
# Out:
# 0.5867018511854784

# %% [markdown]
# ###Would have liked to use acres harvested, but 59% of that data has been withheld, as denoted by '(D)' values in Value column.
#
# From [USDA Census Report, Appendix A](http://www.agcensus.usda.gov/Publications/2012/Full_Report/Volume_1,_Chapter_1_US/usappxa.pdf):
#
# > DISCLOSURE REVIEW
# >
# >After tabulation and review of the aggregates, a comprehensive disclosure review was conducted. NASS is obligated to withhold, under Title 7, U.S. Code, any total that would reveal an individual’s information or allow it to be closely estimated by the public. Cell suppression was used to protect the cells that were determined to be sensitive to a disclosure of information. Farm counts are not considered sensitive and are not subject to disclosure controls.
# >
# >Based on agency standards, data cells were determined to be sensitive to a disclosure of information if they violated either of two criteria rules. The threshold rule was violated if the data cell contained less than three operations. For example, if only one farmer produced turkeys in a county, NASS could not publish the county total for turkey inventory without disclosing that individual’s information. The dominance rule was violated if the distribution of the data within the cell allowed a data user to estimate any respondent’s data too closely. For example, if there are many farmers producing turkeys in a county and some of them were large enough to dominate the cell total, NASS could not publish the county total for turkey inventory without risking disclosing an individual respondent’s data. In both of these situations, the data were suppressed and a “(D)” was placed in the cell in the census publication table. These data cells were referred to as primary suppressions.

# %%
# IF WANT TO USE ACRES HARVESTED: replace null code Values (such as '(D)','(Z)', etc) with 0
#veg_df3.Value = veg_df3.Value.replace(to_replace = r'([A-Z+])', value = 0, regex=True)

# %%
veg_df4 = veg_df3[veg_df3.Data_Item.str.contains("FRESH MARKET") & (veg_df3.Measure == "OPERATIONS WITH AREA HARVESTED")]

# %%
veg_df4.Value = veg_df4.Value.astype(int)
veg_df4.FIPS = veg_df4.FIPS.astype(int)

# %%
# replace null values with 0
veg_df4.Value = veg_df4.Value.fillna(0)

veg_df4.Value = veg_df4.Value.replace(to_replace = ',', value = '', regex=True)

# %%
veg_df4.head()
# Out:
#       State State_ANSI Ag_District  Ag_District_Code   County County_ANSI  \
# 3   Alabama          1  BLACK BELT                40  Autauga         001
# 9   Alabama          1  BLACK BELT                40  Autauga         001
# 13  Alabama          1  BLACK BELT                40  Autauga         001
# 17  Alabama          1  BLACK BELT                40  Autauga         001
# 21  Alabama          1  BLACK BELT                40  Autauga         001
#
#     Commodity                                          Data_Item Domain  \
# 3       Beans  BEANS, SNAP, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 9    Broccoli  BROCCOLI, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 13    Carrots  CARROTS, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
# 17  Cucumbers  CUCUMBERS, FRESH MARKET - OPERATIONS WITH AREA...  TOTAL
# 21   Eggplant  EGGPLANT, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
#
#    Domain_Category  Value    CV  FIPS              Spec_Commodity  \
# 3    NOT SPECIFIED      7  32.6  1001  BEANS, SNAP, FRESH MARKET
# 9    NOT SPECIFIED      1  53.3  1001     BROCCOLI, FRESH MARKET
# 13   NOT SPECIFIED      2  67.1  1001      CARROTS, FRESH MARKET
# 17   NOT SPECIFIED      1  35.3  1001    CUCUMBERS, FRESH MARKET
# 21   NOT SPECIFIED      1  54.5  1001     EGGPLANT, FRESH MARKET
#
#                            Measure
# 3   OPERATIONS WITH AREA HARVESTED
# 9   OPERATIONS WITH AREA HARVESTED
# 13  OPERATIONS WITH AREA HARVESTED
# 17  OPERATIONS WITH AREA HARVESTED
# 21  OPERATIONS WITH AREA HARVESTED
#
# [5 rows x 15 columns]

# %%
# check out California veggies
veg_df4[veg_df4.State == 'California'].head(50)
# Out:
#             State State_ANSI    Ag_District  Ag_District_Code        County  \
# 10796  California          6  CENTRAL COAST                40       Alameda
# 10800  California          6  CENTRAL COAST                40       Alameda
# 10804  California          6  CENTRAL COAST                40       Alameda
# 10808  California          6  CENTRAL COAST                40       Alameda
# 10812  California          6  CENTRAL COAST                40       Alameda
# 10816  California          6  CENTRAL COAST                40       Alameda
# 10820  California          6  CENTRAL COAST                40       Alameda
# 10824  California          6  CENTRAL COAST                40       Alameda
# 10828  California          6  CENTRAL COAST                40       Alameda
# 10832  California          6  CENTRAL COAST                40       Alameda
# 10836  California          6  CENTRAL COAST                40       Alameda
# 10840  California          6  CENTRAL COAST                40       Alameda
# 10844  California          6  CENTRAL COAST                40       Alameda
# 10848  California          6  CENTRAL COAST                40       Alameda
# 10852  California          6  CENTRAL COAST                40       Alameda
# 10856  California          6  CENTRAL COAST                40       Alameda
# 10860  California          6  CENTRAL COAST                40       Alameda
# 10864  California          6  CENTRAL COAST                40       Alameda
# 10868  California          6  CENTRAL COAST                40       Alameda
# 10872  California          6  CENTRAL COAST                40       Alameda
# 10876  California          6  CENTRAL COAST                40       Alameda
# 10880  California          6  CENTRAL COAST                40       Alameda
# 10884  California          6  CENTRAL COAST                40       Alameda
# 10888  California          6  CENTRAL COAST                40       Alameda
# 10892  California          6  CENTRAL COAST                40       Alameda
# 10896  California          6  CENTRAL COAST                40       Alameda
# 10905  California          6  CENTRAL COAST                40       Alameda
# 10911  California          6  CENTRAL COAST                40       Alameda
# 10915  California          6  CENTRAL COAST                40  Contra Costa
# 10919  California          6  CENTRAL COAST                40  Contra Costa
# 10925  California          6  CENTRAL COAST                40  Contra Costa
# 10929  California          6  CENTRAL COAST                40  Contra Costa
# 10933  California          6  CENTRAL COAST                40  Contra Costa
# 10937  California          6  CENTRAL COAST                40  Contra Costa
# 10941  California          6  CENTRAL COAST                40  Contra Costa
# 10945  California          6  CENTRAL COAST                40  Contra Costa
# 10949  California          6  CENTRAL COAST                40  Contra Costa
# 10953  California          6  CENTRAL COAST                40  Contra Costa
# 10957  California          6  CENTRAL COAST                40  Contra Costa
# 10961  California          6  CENTRAL COAST                40  Contra Costa
# 10965  California          6  CENTRAL COAST                40  Contra Costa
# 10969  California          6  CENTRAL COAST                40  Contra Costa
# 10973  California          6  CENTRAL COAST                40  Contra Costa
# 10977  California          6  CENTRAL COAST                40  Contra Costa
# 10981  California          6  CENTRAL COAST                40  Contra Costa
# 10985  California          6  CENTRAL COAST                40  Contra Costa
# 10989  California          6  CENTRAL COAST                40  Contra Costa
# 10993  California          6  CENTRAL COAST                40  Contra Costa
# 10997  California          6  CENTRAL COAST                40  Contra Costa
# 11001  California          6  CENTRAL COAST                40  Contra Costa
#
#       County_ANSI          Commodity  \
# 10796         001              Beans
# 10800         001              Beets
# 10804         001           Broccoli
# 10808         001            Cabbage
# 10812         001            Carrots
# 10816         001        Cauliflower
# 10820         001          Cucumbers
# 10824         001             Greens
# 10828         001              Herbs
# 10832         001            Lettuce
# 10836         001            Lettuce
# 10840         001            Lettuce
# 10844         001            Lettuce
# 10848         001             Melons
# 10852         001             Onions
# 10856         001             Onions
# 10860         001               Peas
# 10864         001            Peppers
# 10868         001            Peppers
# 10872         001           Potatoes
# 10876         001           Pumpkins
# 10880         001             Squash
# 10884         001             Squash
# 10888         001             Squash
# 10892         001         Sweet Corn
# 10896         001           Tomatoes
# 10905         001   Vegetable Totals
# 10911         001  Vegetables, Other
# 10915         013          Asparagus
# 10919         013              Beans
# 10925         013           Broccoli
# 10929         013            Carrots
# 10933         013          Cucumbers
# 10937         013           Eggplant
# 10941         013             Garlic
# 10945         013              Herbs
# 10949         013        Horseradish
# 10953         013            Lettuce
# 10957         013            Lettuce
# 10961         013            Lettuce
# 10965         013            Lettuce
# 10969         013             Melons
# 10973         013             Melons
# 10977         013             Onions
# 10981         013             Onions
# 10985         013               Peas
# 10989         013            Peppers
# 10993         013            Peppers
# 10997         013           Pumpkins
# 11001         013            Spinach
#
#                                                Data_Item Domain  \
# 10796  BEANS, SNAP, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10800  BEETS, FRESH MARKET - OPERATIONS WITH AREA HAR...  TOTAL
# 10804  BROCCOLI, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 10808  CABBAGE, HEAD, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10812  CARROTS, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
# 10816  CAULIFLOWER, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10820  CUCUMBERS, FRESH MARKET - OPERATIONS WITH AREA...  TOTAL
# 10824  GREENS, COLLARD, FRESH MARKET - OPERATIONS WIT...  TOTAL
# 10828  HERBS, FRESH CUT, FRESH MARKET - OPERATIONS WI...  TOTAL
# 10832  LETTUCE, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
# 10836  LETTUCE, HEAD, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10840  LETTUCE, LEAF, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10844  LETTUCE, ROMAINE, FRESH MARKET - OPERATIONS WI...  TOTAL
# 10848  MELONS, CANTALOUP, FRESH MARKET - OPERATIONS W...  TOTAL
# 10852  ONIONS, DRY, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10856  ONIONS, GREEN, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10860  PEAS, GREEN, (EXCL SOUTHERN), FRESH MARKET - O...  TOTAL
# 10864  PEPPERS, BELL, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10868  PEPPERS, CHILE, FRESH MARKET - OPERATIONS WITH...  TOTAL
# 10872  POTATOES, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 10876  PUMPKINS, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 10880  SQUASH, FRESH MARKET - OPERATIONS WITH AREA HA...  TOTAL
# 10884  SQUASH, SUMMER, FRESH MARKET - OPERATIONS WITH...  TOTAL
# 10888  SQUASH, WINTER, FRESH MARKET - OPERATIONS WITH...  TOTAL
# 10892  SWEET CORN, FRESH MARKET - OPERATIONS WITH ARE...  TOTAL
# 10896  TOMATOES, IN THE OPEN, FRESH MARKET - OPERATIO...  TOTAL
# 10905  VEGETABLE TOTALS, IN THE OPEN, FRESH MARKET - ...  TOTAL
# 10911  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...  TOTAL
# 10915  ASPARAGUS, FRESH MARKET - OPERATIONS WITH AREA...  TOTAL
# 10919  BEANS, SNAP, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10925  BROCCOLI, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 10929  CARROTS, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
# 10933  CUCUMBERS, FRESH MARKET - OPERATIONS WITH AREA...  TOTAL
# 10937  EGGPLANT, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 10941  GARLIC, FRESH MARKET - OPERATIONS WITH AREA HA...  TOTAL
# 10945  HERBS, FRESH CUT, FRESH MARKET - OPERATIONS WI...  TOTAL
# 10949  HORSERADISH, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10953  LETTUCE, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
# 10957  LETTUCE, HEAD, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10961  LETTUCE, LEAF, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10965  LETTUCE, ROMAINE, FRESH MARKET - OPERATIONS WI...  TOTAL
# 10969  MELONS, CANTALOUP, FRESH MARKET - OPERATIONS W...  TOTAL
# 10973  MELONS, WATERMELON, FRESH MARKET - OPERATIONS ...  TOTAL
# 10977  ONIONS, DRY, FRESH MARKET - OPERATIONS WITH AR...  TOTAL
# 10981  ONIONS, GREEN, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10985  PEAS, CHINESE (SUGAR & SNOW), FRESH MARKET - O...  TOTAL
# 10989  PEPPERS, BELL, FRESH MARKET - OPERATIONS WITH ...  TOTAL
# 10993  PEPPERS, CHILE, FRESH MARKET - OPERATIONS WITH...  TOTAL
# 10997  PUMPKINS, FRESH MARKET - OPERATIONS WITH AREA ...  TOTAL
# 11001  SPINACH, FRESH MARKET - OPERATIONS WITH AREA H...  TOTAL
#
#       Domain_Category Value    CV  FIPS  \
# 10796   NOT SPECIFIED     3  29.8  6001
# 10800   NOT SPECIFIED    10  25.7  6001
# 10804   NOT SPECIFIED     1  12.9  6001
# 10808   NOT SPECIFIED     3  31.5  6001
# 10812   NOT SPECIFIED     1  19.5  6001
# 10816   NOT SPECIFIED     1  17.4  6001
# 10820   NOT SPECIFIED     3  25.2  6001
# 10824   NOT SPECIFIED     2  46.3  6001
# 10828   NOT SPECIFIED     2  33.6  6001
# 10832   NOT SPECIFIED    15  18.3  6001
# 10836   NOT SPECIFIED     1  16.4  6001
# 10840   NOT SPECIFIED    15  23.3  6001
# 10844   NOT SPECIFIED     1  14.9  6001
# 10848   NOT SPECIFIED     2  23.6  6001
# 10852   NOT SPECIFIED     3  21.5  6001
# 10856   NOT SPECIFIED     9  46.5  6001
# 10860   NOT SPECIFIED     1  30.4  6001
# 10864   NOT SPECIFIED     2  26.3  6001
# 10868   NOT SPECIFIED     4  29.2  6001
# 10872   NOT SPECIFIED     2  29.3  6001
# 10876   NOT SPECIFIED     1    24  6001
# 10880   NOT SPECIFIED    10  18.8  6001
# 10884   NOT SPECIFIED     8  19.7  6001
# 10888   NOT SPECIFIED     2  22.8  6001
# 10892   NOT SPECIFIED     2  23.2  6001
# 10896   NOT SPECIFIED    35  19.9  6001
# 10905   NOT SPECIFIED    38  19.9  6001
# 10911   NOT SPECIFIED     3  36.2  6001
# 10915   NOT SPECIFIED     1  28.5  6013
# 10919   NOT SPECIFIED    11  29.8  6013
# 10925   NOT SPECIFIED     1  12.9  6013
# 10929   NOT SPECIFIED     1  19.5  6013
# 10933   NOT SPECIFIED     3  25.2  6013
# 10937   NOT SPECIFIED     6  34.4  6013
# 10941   NOT SPECIFIED     2    24  6013
# 10945   NOT SPECIFIED     5  33.6  6013
# 10949   NOT SPECIFIED     1  22.1  6013
# 10953   NOT SPECIFIED     9  18.3  6013
# 10957   NOT SPECIFIED     3  16.4  6013
# 10961   NOT SPECIFIED     6  23.3  6013
# 10965   NOT SPECIFIED     1  14.9  6013
# 10969   NOT SPECIFIED     7  23.6  6013
# 10973   NOT SPECIFIED     4  25.5  6013
# 10977   NOT SPECIFIED     9  21.5  6013
# 10981   NOT SPECIFIED     1  46.5  6013
# 10985   NOT SPECIFIED     5  33.5  6013
# 10989   NOT SPECIFIED     2  26.3  6013
# 10993   NOT SPECIFIED     4  29.2  6013
# 10997   NOT SPECIFIED     5    24  6013
# 11001   NOT SPECIFIED     5  30.2  6013
#
#                                      Spec_Commodity  \
# 10796                    BEANS, SNAP, FRESH MARKET
# 10800                          BEETS, FRESH MARKET
# 10804                       BROCCOLI, FRESH MARKET
# 10808                  CABBAGE, HEAD, FRESH MARKET
# 10812                        CARROTS, FRESH MARKET
# 10816                    CAULIFLOWER, FRESH MARKET
# 10820                      CUCUMBERS, FRESH MARKET
# 10824                GREENS, COLLARD, FRESH MARKET
# 10828               HERBS, FRESH CUT, FRESH MARKET
# 10832                        LETTUCE, FRESH MARKET
# 10836                  LETTUCE, HEAD, FRESH MARKET
# 10840                  LETTUCE, LEAF, FRESH MARKET
# 10844               LETTUCE, ROMAINE, FRESH MARKET
# 10848              MELONS, CANTALOUP, FRESH MARKET
# 10852                    ONIONS, DRY, FRESH MARKET
# 10856                  ONIONS, GREEN, FRESH MARKET
# 10860   PEAS, GREEN, (EXCL SOUTHERN), FRESH MARKET
# 10864                  PEPPERS, BELL, FRESH MARKET
# 10868                 PEPPERS, CHILE, FRESH MARKET
# 10872                       POTATOES, FRESH MARKET
# 10876                       PUMPKINS, FRESH MARKET
# 10880                         SQUASH, FRESH MARKET
# 10884                 SQUASH, SUMMER, FRESH MARKET
# 10888                 SQUASH, WINTER, FRESH MARKET
# 10892                     SWEET CORN, FRESH MARKET
# 10896          TOMATOES, IN THE OPEN, FRESH MARKET
# 10905  VEGETABLE TOTALS, IN THE OPEN, FRESH MARKET
# 10911              VEGETABLES, OTHER, FRESH MARKET
# 10915                      ASPARAGUS, FRESH MARKET
# 10919                    BEANS, SNAP, FRESH MARKET
# 10925                       BROCCOLI, FRESH MARKET
# 10929                        CARROTS, FRESH MARKET
# 10933                      CUCUMBERS, FRESH MARKET
# 10937                       EGGPLANT, FRESH MARKET
# 10941                         GARLIC, FRESH MARKET
# 10945               HERBS, FRESH CUT, FRESH MARKET
# 10949                    HORSERADISH, FRESH MARKET
# 10953                        LETTUCE, FRESH MARKET
# 10957                  LETTUCE, HEAD, FRESH MARKET
# 10961                  LETTUCE, LEAF, FRESH MARKET
# 10965               LETTUCE, ROMAINE, FRESH MARKET
# 10969              MELONS, CANTALOUP, FRESH MARKET
# 10973             MELONS, WATERMELON, FRESH MARKET
# 10977                    ONIONS, DRY, FRESH MARKET
# 10981                  ONIONS, GREEN, FRESH MARKET
# 10985   PEAS, CHINESE (SUGAR & SNOW), FRESH MARKET
# 10989                  PEPPERS, BELL, FRESH MARKET
# 10993                 PEPPERS, CHILE, FRESH MARKET
# 10997                       PUMPKINS, FRESH MARKET
# 11001                        SPINACH, FRESH MARKET
#
#                               Measure
# 10796  OPERATIONS WITH AREA HARVESTED
# 10800  OPERATIONS WITH AREA HARVESTED
# 10804  OPERATIONS WITH AREA HARVESTED
# 10808  OPERATIONS WITH AREA HARVESTED
# 10812  OPERATIONS WITH AREA HARVESTED
# 10816  OPERATIONS WITH AREA HARVESTED
# 10820  OPERATIONS WITH AREA HARVESTED
# 10824  OPERATIONS WITH AREA HARVESTED
# 10828  OPERATIONS WITH AREA HARVESTED
# 10832  OPERATIONS WITH AREA HARVESTED
# 10836  OPERATIONS WITH AREA HARVESTED
# 10840  OPERATIONS WITH AREA HARVESTED
# 10844  OPERATIONS WITH AREA HARVESTED
# 10848  OPERATIONS WITH AREA HARVESTED
# 10852  OPERATIONS WITH AREA HARVESTED
# 10856  OPERATIONS WITH AREA HARVESTED
# 10860  OPERATIONS WITH AREA HARVESTED
# 10864  OPERATIONS WITH AREA HARVESTED
# 10868  OPERATIONS WITH AREA HARVESTED
# 10872  OPERATIONS WITH AREA HARVESTED
# 10876  OPERATIONS WITH AREA HARVESTED
# 10880  OPERATIONS WITH AREA HARVESTED
# 10884  OPERATIONS WITH AREA HARVESTED
# 10888  OPERATIONS WITH AREA HARVESTED
# 10892  OPERATIONS WITH AREA HARVESTED
# 10896  OPERATIONS WITH AREA HARVESTED
# 10905  OPERATIONS WITH AREA HARVESTED
# 10911  OPERATIONS WITH AREA HARVESTED
# 10915  OPERATIONS WITH AREA HARVESTED
# 10919  OPERATIONS WITH AREA HARVESTED
# 10925  OPERATIONS WITH AREA HARVESTED
# 10929  OPERATIONS WITH AREA HARVESTED
# 10933  OPERATIONS WITH AREA HARVESTED
# 10937  OPERATIONS WITH AREA HARVESTED
# 10941  OPERATIONS WITH AREA HARVESTED
# 10945  OPERATIONS WITH AREA HARVESTED
# 10949  OPERATIONS WITH AREA HARVESTED
# 10953  OPERATIONS WITH AREA HARVESTED
# 10957  OPERATIONS WITH AREA HARVESTED
# 10961  OPERATIONS WITH AREA HARVESTED
# 10965  OPERATIONS WITH AREA HARVESTED
# 10969  OPERATIONS WITH AREA HARVESTED
# 10973  OPERATIONS WITH AREA HARVESTED
# 10977  OPERATIONS WITH AREA HARVESTED
# 10981  OPERATIONS WITH AREA HARVESTED
# 10985  OPERATIONS WITH AREA HARVESTED
# 10989  OPERATIONS WITH AREA HARVESTED
# 10993  OPERATIONS WITH AREA HARVESTED
# 10997  OPERATIONS WITH AREA HARVESTED
# 11001  OPERATIONS WITH AREA HARVESTED
#
# [50 rows x 15 columns]

# %%
# Create pivot table
veg_pt = pd.pivot_table(veg_df4, values = 'Value', rows = 'FIPS', cols= 'Commodity', aggfunc = np.sum)

# %% [markdown]
# **Lots of NaN values in the pivot table. Will convert to zeros.**

# %%
veg_pt.head()
# Out:
# Commodity  Artichokes  Asparagus  Beans  Beets  Broccoli  Brussels Sprouts  \
# FIPS
# 1001              NaN        NaN      7    NaN         1               NaN
# 1003              NaN        NaN     21    NaN         3               NaN
# 1005              NaN        NaN    NaN    NaN       NaN               NaN
# 1007              NaN        NaN      2    NaN       NaN               NaN
# 1009              NaN        NaN     38    NaN         1               NaN
#
# Commodity  Cabbage  Carrots  Cauliflower  Celery  Chicory  Cucumbers  Daikon  \
# FIPS
# 1001           NaN        2          NaN     NaN      NaN          1     NaN
# 1003           NaN        1          NaN     NaN      NaN         14     NaN
# 1005           NaN      NaN          NaN     NaN      NaN        NaN     NaN
# 1007           NaN      NaN          NaN     NaN      NaN        NaN     NaN
# 1009             2      NaN            1     NaN      NaN         22     NaN
#
# Commodity  Eggplant  Escarole & Endive  Garlic  Ginseng  Greens  Herbs  \
# FIPS
# 1001              1                NaN     NaN      NaN       3    NaN
# 1003              3                NaN     NaN      NaN     NaN    NaN
# 1005            NaN                NaN     NaN      NaN       1    NaN
# 1007            NaN                NaN     NaN      NaN       2    NaN
# 1009              3                NaN     NaN      NaN      11      1
#
# Commodity  Horseradish
# FIPS
# 1001               NaN ...
# 1003               NaN ...
# 1005               NaN ...
# 1007               NaN ...
# 1009               NaN ...
#
# [5 rows x 40 columns]

# %%
veg_pt = veg_pt.fillna(0)
veg_pt.head()
# Out:
# Commodity  Artichokes  Asparagus  Beans  Beets  Broccoli  Brussels Sprouts  \
# FIPS
# 1001                0          0      7      0         1                 0
# 1003                0          0     21      0         3                 0
# 1005                0          0      0      0         0                 0
# 1007                0          0      2      0         0                 0
# 1009                0          0     38      0         1                 0
#
# Commodity  Cabbage  Carrots  Cauliflower  Celery  Chicory  Cucumbers  Daikon  \
# FIPS
# 1001             0        2            0       0        0          1       0
# 1003             0        1            0       0        0         14       0
# 1005             0        0            0       0        0          0       0
# 1007             0        0            0       0        0          0       0
# 1009             2        0            1       0        0         22       0
#
# Commodity  Eggplant  Escarole & Endive  Garlic  Ginseng  Greens  Herbs  \
# FIPS
# 1001              1                  0       0        0       3      0
# 1003              3                  0       0        0       0      0
# 1005              0                  0       0        0       1      0
# 1007              0                  0       0        0       2      0
# 1009              3                  0       0        0      11      1
#
# Commodity  Horseradish
# FIPS
# 1001                 0 ...
# 1003                 0 ...
# 1005                 0 ...
# 1007                 0 ...
# 1009                 0 ...
#
# [5 rows x 40 columns]

# %%
veg_pt.to_csv('vegetables.csv')
